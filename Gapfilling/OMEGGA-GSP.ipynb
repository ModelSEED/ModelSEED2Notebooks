# %% [markdown]
# # Configure KBase Jupyter Dev Environment
# <sub><sup>(contact chenry@anl.gov with questions)</sub></sup>

# %%
import platform
print("python version " + platform.python_version())
import sys
import json
from json import dump
import os
import pandas as pd
from pandas import DataFrame, read_csv, concat, set_option
from os.path import exists
from pathlib import Path
import logging
import shutil
from configparser import ConfigParser

config = ConfigParser()
if not exists(str(Path.home()) + '/.kbase/config'):    
    if exists("/scratch/shared/code/sharedconfig.cfg"):
        shutil.copyfile("/scratch/shared/code/sharedconfig.cfg",str(Path.home()) + '/.kbase/config')
    else:
        print("You much create a config file in ~/.kbase/config before running this notebook. See instructions: https://docs.google.com/document/d/1fQ6iS_uaaZKbjWtw1MgzqilklttIibNO9XIIJWgxWKo/edit")
        sys.exit(1)
config.read(str(Path.home()) + '/.kbase/config')
paths = config.get("DevEnv","syspaths").split(";")
codebase = config.get("DevEnv","codebase",fallback="")
for i,filepath in enumerate(paths):
    if filepath[0:1] != "/":
        paths[i] = codebase+"/"+filepath
sys.path = paths + sys.path

from chenry_utility_module.kbdevutils import KBDevUtils
kbdevutil = KBDevUtils("ModelSEED2")
from modelseedpy import AnnotationOntology, MSPackageManager, MSModelUtil, MSBuilder, MSATPCorrection, MSGapfill, MSModelReport
from modelseedpy.core.mstemplate import MSTemplateBuilder
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
msrecon = kbdevutil.msseedrecon()
annoapi = kbdevutil.anno_client(native_python_api=True)
msrecon.core_template = msrecon.get_template(msrecon.templates["core"],None)

annoapi = kbdevutil.anno_client(native_python_api=True)

com_media = msrecon.get_media("KBaseMedia/Complete")
gmm_media = msrecon.get_media("KBaseMedia/Carbon-D-Glucose")
auxo_media = msrecon.get_media("94026/Auxotrophy_media")
# Out:
# python version 3.9.13
# KBBaseModules 0.0.1
# Output files printed to:/Users/chenry/workspace/Notebooks//ModelSEED2//sessions/default/output when using KBDevUtils.output_dir
# modelseedpy 0.3.3
# cobrakbase 0.3.1

# %% [markdown]
# # Code cell to use to run pipeline on all of Aimee's genomes

# %%
genome_prefix = ["G7","G5","G1","G16","G14","G12","G11"]
for prefix in genome_prefix:
    genome_id = "167956/"+prefix+"_RAST_prokka_assembly.glm4ec"
    output = msrecon.build_metabolic_models({
        "workspace":168913,
        "genome_refs":[genome_id],
        "run_gapfilling":False,
        "atp_safe":True,
        "forced_atp_list":[],
        "gapfilling_media_list":[],
        "suffix":".mdl",
        "core_template":"auto",
        "gs_template":"auto",
        "template_reactions_only":True,
        "output_core_models":False,
        "save_report_to_kbase":False,
        "change_to_complete":0,
        "gapfilling_mode":"Independent",
        "max_gapfilling":3,
        "gapfilling_delta":1
    })
# Out:
# 1707635591.590782 INFO: build_metabolic_models:{
#     "workspace": 168913,
#     "genome_refs": [
#         "167956/G14_RAST_prokka_assembly.glm4ec"
#     ],
#     "run_gapfilling": false,
#     "atp_safe": true,
#     "forced_atp_list": [],
#     "gapfilling_media_list": [],
#     "suffix": ".mdl",
#     "core_template": "auto",
#     "gs_template": "auto",
#     "template_reactions_only": true,
#     "output_core_models": false,
#     "save_report_to_kbase": false,
#     "change_to_complete": 0,
#     "gapfilling_mode": "Independent",
#     "max_gapfilling": 3,
#     "gapfilling_delta": 1
# }
# /Users/chenry/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estim
 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1f4caf0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000007864', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1f4c730>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000018833', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1f4c430>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000001260', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1f4c130>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000000860', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1f43bb0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000008131', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1f438b0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000020980', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1f434f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000019885', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1f43130>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000028413', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1f39d30>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000022710', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1f39a30>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000020822', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1f39730>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000020823', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c202f4f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000018718', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1f39070>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000024526', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1fdb430>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000003209', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98e6a30>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000003271', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98e68b0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000025403', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1fdb430>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000003209', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98e6370>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000003627', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98dcd30>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000006879', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c1f39070>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000024526', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98dc4f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000003343', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98dc370>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000039554', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98dc070>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000001549', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98d2d30>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000001198', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98d2a30>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000001541', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98d2670>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000030665', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98d22b0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000026367', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98c9f70>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000000825', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98c9c70>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000007805', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98c9970>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000007804', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98c95b0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000025957', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98bf970>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000003519', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98bf7f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000034186', 'ontology': 'SSO', 'probability': 0.5}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 1.0}]}
# {<modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0c20827f0>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000009137', 'ontology': 'SSO', 'probability': 0.5}], <modelseedpy.core.annotationontology.AnnotationOntologyTerm object at 0x7fa0b98b4f70>: [{'event': 'RAST-annotate_genome', 'term': 'SSO:000020814', 'ontology': 'SSO', 'probability': 0.5}]}
# ...
# 1707635640.7399948 INFO: Trimethylamine.H2/rxn00062_c0:rxn24610_c0> needed:0.0 with min obj:0.01
# 1707635640.7415848 INFO: Trimethylamine.H2/rxn00062_c0:rxn03127_c0> needed:0.0 with min obj:0.01
# 1707635640.743228 INFO: Trimethylamine.H2/rxn00062_c0:rxn24613_c0> needed:0.0 with min obj:0.01
# 1707635640.744941 INFO: Trimethylamine.H2/rxn00062_c0:rxn09318_c0< needed:0.0 with min obj:0.01
# 1707635640.746549 INFO: Trimethylamine.H2/rxn00062_c0:rxn15961_c0> needed:0.0 with min obj:0.01
# 1707635640.748092 INFO: Trimethylamine.H2/rxn00062_c0:rxn03126_c0> needed:0.0 with min obj:0.01
# 1707635640.749687 INFO: Trimethylamine.H2/rxn00062_c0:rxn24611_c0> needed:0.0 with min obj:0.01
# 1707635640.876472 INFO: max_gapfilling: 3, best_score: 0.0
# 1707635640.876981 INFO: Setting FBAModel computed_attributes to mdlutl attributes
# 1707635640.922317 INFO: Glyc.O2/rxn00062_c0:rxn05581_c0< needed:0.0 with min obj:2
# 1707635640.9599302 INFO: Setting FBAModel computed_attributes to mdlutl attributes
# Adding gapfilling {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c4bc10>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False, 'new': {'EX_cpd00441_e0': '<', 'rxn24608_c0': '>', 'rxn24609_c0': '>', 'rxn24610_c0': '>', 'rxn03127_c0': '>', 'rxn24613_c0': '>', 'rxn09318_c0': '<', 'rxn15961_c0': '>', 'rxn03126_c0': '>', 'rxn24611_c0': '>'}, 'reversed': {}}
# {<modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c43f10>: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c43f10>, 'target': 'rxn00062_c0', 'minobjective': 5, 'binary_check': False, 'new': {'EX_cpd00027_e0': '<', 'rxn05226_c0': '>'}, 'reversed': {}}, <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c436a0>: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c436a0>, 'target': 'rxn00062_c0', 'minobjective': 2, 'binary_check': False, 'new': {'rxn05581_c0': '<'}, 'reversed': {}}, <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c43370>: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c43370>, 'target': 'rxn00062_c0', 'minobjective': 2, 'binary_check': False, 'new': {'rxn09269_c0': '>'}, 'reversed': {}}, <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c3a790>: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c3a790>, 'target': 'rxn00062_c0', 'minobjective': 2, 'binary_check': False, 'new': {'EX_cpd00024_e0': '<', 'rxn05493_c0': '>'}, 'reversed': {}}, <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c3a970>: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c3a970>, 'target': 'rxn00062_c0', 'minobjective': 2, 'binary_check': False, 'new': {'EX_cpd00159_e0': '<', 'rxn05602_c0': '>'}, 'reversed': {}}, <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c3aa00>: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c3aa00>, 'target': 'rxn00062_c0', 'minobjective': 2, 'binary_check': False, 'new': {'rxn01057_c0': '<'}, 'reversed': {}}, <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c3a5b0>: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c3a5b0>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False, 'new': {'EX_cpd00027_e0': '<', 'rxn05226_c0': '>'}, 'reversed': {}}, <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c3a9d0>: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c3a9d0>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False, 'new': {'rxn03079_c0': '<', 'rxn46184_c0': '<', 'rxn05759_c0': '>', 'rxn00545_c0': '>', 'rxn13974_c0': '<', 'rxn06299_c0': '>', 'rxn15962_c0': '<', 'rxn17445_c0': '>', 'rxn02480_c0': '<', 'rxn03085_c0': '>', 'rxn40505_c0': '<'}, 'reversed': {}}, <modelseedpy.core.msmedia.MSMedia object at 0x7fa095f15e20>: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa095f15e20>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False, 'new': {'rxn05581_c0': '<'}, 'reversed': {}}, <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c47fa0>: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c47fa0>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False, 'new': {'rxn05759_c0': '>', 'rxn13974_c0': '<', 'rxn09269_c0': '>'}, 'reversed': {}}, <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c47b20>: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c47b20>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False, 'new': {'EX_cpd00024_e0': '<', 'rxn05493_c0': '>'}, 'reversed': {}}, <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c47c40>: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c47c40>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False, 'new': {'EX_cpd00159_e0': '<', 'rxn05602_c0': '>', 'rxn05759_c0': '>', 'rxn13974_c0': '<'}, 'reversed': {}}, <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c471f0>: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c471f0>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False, 'new': {'rxn05759_c0': '>', 'rxn13974_c0': '<', 'rxn01057_c0': '<'}, 'reversed': {}}, <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c47e50>: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c47e50>, 'target': 'rxn00062_c ...
# Adding gapfilling {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c436a0>, 'target': 'rxn00062_c0', 'minobjective': 2, 'binary_check': False, 'new': {'rxn05581_c0': '<'}, 'reversed': {}}
# 1707635641.004999 INFO: rxn05581_c0< not needed:15.125
# 1707635641.006742 INFO: Succ.O2/rxn00062_c0:rxn09269_c0> needed:0.0 with min obj:2
# 1707635641.044395 INFO: Setting FBAModel computed_attributes to mdlutl attributes
# 1707635641.093932 INFO: rxn05581_c0< not needed:12.25
# 1707635641.095754 INFO: rxn09269_c0> not needed:12.25
# 1707635641.097609 INFO: Dlac.O2/rxn00062_c0:rxn01057_c0< needed:0.0 with min obj:2
# 1707635641.139013 INFO: Setting FBAModel computed_attributes to mdlutl attributes
# 1707635641.1812632 INFO: Glyc/rxn00062_c0:rxn05581_c0< needed:0.0 with min obj:0.01
# 1707635641.183018 INFO: rxn09269_c0> not needed:0.33333333333333304
# 1707635641.184222 INFO: rxn01057_c0< not needed:0.33333333333333304
# 1707635641.220025 INFO: Setting FBAModel computed_attributes to mdlutl attributes
# 1707635641.220865 INFO: Setting FBAModel computed_attributes to mdlutl attributes
# Adding gapfilling {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c43370>, 'target': 'rxn00062_c0', 'minobjective': 2, 'binary_check': False, 'new': {'rxn09269_c0': '>'}, 'reversed': {}}
# Adding gapfilling {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x7fa0a1c3aa00>, 'target': 'rxn00062_c0', 'minobjective': 2, 'binary_check': False, 'new': {'rxn01057_c0': '<'}, 'reversed': {}}
FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   f.write(model_summary_df_styled.render(escape=False))
# /Users/chenry/code//ModelSEEDpy/modelseedpy/core/msmodelreport.py:619: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   f.write(gapfillings_analysis_df_styled.render(escape=False))
# /Users/chenry/code//ModelSEEDpy/modelseedpy/core/msmodelreport.py:630: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   f.write(atp_analysis_df_styled.render(escape=False))
# 1707635667.2895842 INFO: Compartment `e0` sounds like an external compartment. Using this one without counting boundary reactions.
# Module Path: /Users/chenry/code/ModelSEEDpy/modelseedpy/core/../data/
# Unique biomass reactions identified: 1
# Biomass Reaction IDs: bio1
#
# First 2 reactions:
# {'id': 'rxn02201_c0', 'name': '2-amino-4-hydroxy-6-hydroxymethyl-7,8-dihydropteridine-diphosphate:4-aminobenzoate 2-amino-4-hydroxydihydropteridine-6-methenyltransferase [c0]', 'equation': 'ABEE [c0] + 2-Amino-4-hydroxy-6-hydroxymethyl-7-8-dihydropteridinediphosphate [c0] --> PPi [c0] + H+ [c0] + Dihydropteroate [c0]', 'genes': '(DFPKEECB_04859_mRNA or DFPKEECB_04859) or (DFPKEECB_04861 or DFPKEECB_04861_mRNA)', 'gapfilling': ''}
# {'id': 'rxn00351_c0', 'name': 'gamma-L-glutamyl-L-cysteine:glycine ligase (ADP-forming) [c0]', 'equation': 'ATP [c0] + Glycine [c0] + gamma-Glutamylcysteine [c0] --> ADP [c0] + Phosphate [c0] + GSH [c0] + H+ [c0]', 'genes': 'DFPKEECB_04624 or DFPKEECB_02878 or DFPKEECB_02878_mRNA or DFPKEECB_04624_mRNA', 'gapfilling': ''}
#
# First 2 compounds:
# {'id': 'cpd00443_c0', 'name': 'ABEE [c0]', 'formula': 'C7H6NO2', 'charge': -1, 'compartment': 'c0'}
# {'id': 'cpd02920_c0', 'name': '2-Amino-4-hydroxy-6-hydroxymethyl-7-8-dihydropteridinediphosphate [c0]', 'formula': 'C7H9N5O8P2', 'charge': -2, 'compartment': 'c0'}
#
# First 2 genes:
# {'gene': 'DFPKEECB_04859_mRNA', 'reactions': 'rxn02201_c0; rxn02503_c0; rxn02200_c0'}
# {'gene': 'DFPKEECB_04861', 'reactions': 'rxn02201_c0; rxn02200_c0'}
#
# First 2 biomass compounds:
# {'biomass_reaction_id': 'bio1', 'biomass_compound_id': 'cpd11461_c0', 'name': 'DNA [c0]', 'coefficient': -0.0121667, 'compartment': 'c0'}
# {'biomass_reaction_id': 'bio1', 'biomass_compound_id': 'cpd11463_c0', 'name': 'Protein [c0]', 'coefficient': -0.5441666, 'compartment': 'c0'}
#
# First 2 gapfilling entries:
# {'reaction_id': 'rxn05581_c0', 'reaction_name': 'RXN0-1683.ce.maizeexp.GLYCEROL_GLYCEROL', 'media': 'Glyc.O2; Glyc', 'direction': '<', 'target': 'rxn00062_c0', 'gapfilling_sensitivity_id': [], 'gapfilling_sensitivity_name': []}
# {'reaction_id': 'rxn09269_c0', 'reaction_name': 'TRANS-RXN-121.cp', 'media': 'Succ.O2', 'direction': '>', 'target': 'rxn00062_c0', 'gapfilling_sensitivity_id': [], 'gapfilling_sensitivity_name': []}
all_scores = {}
for prefix in genome_prefix:
    genome_id = "167956/"+prefix+"_RAST_prokka_assembly.glm4ec"
    annoont = AnnotationOntology.from_kbase_data(annoapi.get_annotation_ontology_events({
        "input_ref" : genome_id
    }),genome_id)
    all_scores[genome_id] = annoont.get_reaction_gene_hash(feature_type="gene")
kbdevutil.save("all_reaction_scores",all_scores)
# Out:
# 1707859239.9389849 INFO: get_annotation_ontology_events:{
#     "input_ref": "167956/G8_RAST_prokka_assembly.glm4ec"
# }

# %% [markdown]
# # Running gapfilling

# %%
def gapfill_phenotypes(all_scores, prefix, genome_media, msrecon, all_solutions, kbdevutil):
    model = msrecon.get_model("168913/"+prefix+"_RAST_prokka_assembly.glm4ec.mdl")
    template = msrecon.get_template(model.model.template_ref)
    tests = model.get_atp_tests()
    msgapfill = MSGapfill(
        model,
        [template],
        [],
        tests,
        blacklist=[],
        default_target="bio1",
        minimum_obj=0.01,
        reaction_scores=all_scores["167956/"+prefix+"_RAST_prokka_assembly.glm4ec"],
    )
    media_list = []
    for item in genome_media["167956/"+prefix+"_RAST_prokka_assembly.glm4ec"]:
        media = msrecon.get_media(item)
        media_list.append(media)
    solutions = msgapfill.run_multi_gapfill(media_list,target="bio1",gapfilling_mode="Cumulative")
    all_solutions["167956/"+prefix+"_RAST_prokka_assembly.glm4ec"] = {}
    for media in solutions:
        all_solutions["167956/"+prefix+"_RAST_prokka_assembly.glm4ec"][media.info.id] = solutions[media]
        all_solutions["167956/"+prefix+"_RAST_prokka_assembly.glm4ec"][media.info.id]["media"] = media.info.id
    kbdevutil.save("all_solutions",all_solutions)
    msrecon.save_model(model,168913,None,".gf")

#Loading precomputed scores and media lists
genome_prefix = ["G8","G7","G5","G1","G16","G12","G11"]
all_scores = kbdevutil.load("all_reaction_scores")
genome_media = kbdevutil.load("genome_media")
#Iterating over genomes
all_solutions = {}

args = []
for prefix in genome_prefix:
    args.append((all_scores, prefix, genome_media, msrecon, all_solutions, kbdevutil))

# define the parallelized pool
#from multiprocess import Pool
#from os import cpu_count
#pool = Pool(int(cpu_count()/3))
# run the parallelized job
#pool.map(gapfill_phenotypes, args)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/chenry/opt/anaconda3/lib/python3.9/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/chenry/opt/anaconda3/lib/python3.9/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
# TypeError: gapfill_phenotypes() missing 5 required positional arguments: 'prefix', 'genome_media', 'msrecon', 'all_solutions', and 'kbdevutil'
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /var/folders/ph/360gp1jx5zg7qyqv076prl240000gn/T/ipykernel_63726/1905435600.py in <module>
#      41 pool = Pool(int(cpu_count()/3))
#      42 # run the parallelized job
# ---> 43 pool.map(gapfill_phenotypes, args)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/multiprocess/pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/multiprocess/pool.py in get(self, timeout)
#     769             return self._value
#     770         else:
# --> 771             raise self._value
#     772
#     773     def _set(self, i, obj):
#
# TypeError: gapfill_phenotypes() missing 5 required positional arguments: 'prefix', 'genome_media', 'msrecon', 'all_solutions', and 'kbdevutil'

# %%
#Loading precomputed scores and media lists
genome_prefix = ["G8","G7","G5","G16","G12","G11"]
genome_prefix = ["G14"]
all_solutions = kbdevutil.load("all_solutions")
all_scores = kbdevutil.load("all_reaction_scores")
genome_media = kbdevutil.load("genome_media")
#Iterating over genomes
for prefix in genome_prefix:
    model = msrecon.get_model("168913/"+prefix+"_RAST_prokka_assembly.glm4ec.mdl")
    template = msrecon.get_template(model.model.template_ref)
    tests = model.get_atp_tests()
    msgapfill = MSGapfill(
        model,
        [template],
        [],
        tests,
        blacklist=[],
        default_target="bio1",
        minimum_obj=0.01,
        reaction_scores=all_scores["167956/"+prefix+"_RAST_prokka_assembly.glm4ec"],
    )
    #msgapfill.gfmodel.reactions.get_by_id("rxn00392_c0").lower_bound = -1000
    #msgapfill.gfmodel.reactions.get_by_id("rxn02314_c0").lower_bound = -1000
    #msgapfill.gfmodel.reactions.get_by_id("rxn00157_c0").lower_bound = -1000
    media_list = [msrecon.get_media("KBaseMedia/Carbon-D-Glucose")]
    for item in genome_media["167956/"+prefix+"_RAST_prokka_assembly.glm4ec"]:
        media = msrecon.get_media(item)
        media_list.append(media)
    solutions = msgapfill.run_multi_gapfill(media_list,target="bio1",gapfilling_mode="Cumulative")
    msrecon.save_model(model,168913,None,".gf")
    all_solutions["167956/"+prefix+"_RAST_prokka_assembly.glm4ec"] = {}
    for media in solutions:
        all_solutions["167956/"+prefix+"_RAST_prokka_assembly.glm4ec"][media.info.id] = solutions[media]
        all_solutions["167956/"+prefix+"_RAST_prokka_assembly.glm4ec"][media.info.id]["media"] = media.info.id
    kbdevutil.save("all_solutions",all_solutions)
# Out:
# 1707855839.055524 INFO: metabolites 1368
# 1707855839.530366 INFO: reactions 1401
# 1707855840.2561579 INFO: Default biomass: [bio1]
# 1707855843.6373692 WARNING: Ignoring reaction 'rxn00062_c0' since it already exists.
# 1707855843.844377 WARNING: Ignoring reaction 'rxn00062_c0' since it already exists.
# Getting tests from attributes
# 1707855864.8306491 INFO: Objective with gapfill database:12.511390713231771; min objective:0.01
# 1707855873.357622 INFO: Objective with gapfill database:12.511390713232252; min objective:0.01
# 1707855874.437479 INFO: Objective with gapfill database:13.76252978455538; min objective:0.01
# 1707855875.585793 INFO: Objective with gapfill database:13.76252978455537; min objective:0.01
# 1707855876.7923431 INFO: Objective with gapfill database:13.762529784555163; min objective:0.01
# 1707855877.905958 INFO: Objective with gapfill database:12.511390713231966; min objective:0.01
# 1707855879.143583 INFO: Objective with gapfill database:12.511390713231966; min objective:0.01
# 1707855884.9975958 INFO: Objective with gapfill database:13.762529784555163; min objective:0.01
# 1707855886.277948 INFO: Objective with gapfill database:12.511390713231966; min objective:0.01
# 1707855887.56246 INFO: Objective with gapfill database:12.511390713231966; min objective:0.01
# 1707855888.9616 INFO: Objective with gapfill database:12.511390713231966; min objective:0.01
# Failed:<rxn00146_c0
# Failed:>rxn10124_c0
# 1707857664.933011 INFO: Carbon-D-Glucose/bio1:rxn09106_c0> needed:0.0 with min obj:0.01
# 1707857664.936485 INFO: Carbon-D-Glucose/bio1:rxn01539_c0< needed:0.0 with min obj:0.01
# 1707857664.939872 INFO: Carbon-D-Glucose/bio1:rxn10094_c0> needed:0.0 with min obj:0.01
# 1707857665.001468 INFO: Carbon-D-Glucose/bio1:rxn01508_c0> needed:0.0 with min obj:0.01
# 1707857665.0058508 INFO: Carbon-D-Glucose/bio1:rxn03150_c0> needed:0.0 with min obj:0.01
# 1707857665.009879 INFO: Carbon-D-Glucose/bio1:rxn09310_c0> needed:0.0 with min obj:0.01
# 1707857665.013555 INFO: Carbon-D-Glucose/bio1:rxn01213_c0> needed:0.0 with min obj:0.01
# 1707857665.01734 INFO: Carbon-D-Glucose/bio1:rxn02304_c0> needed:0.0 with min obj:0.01
# 1707857665.020888 INFO: Carbon-D-Glucose/bio1:rxn12239_c0> needed:0.0 with min obj:0.01
# 1707857665.024259 INFO: Carbon-D-Glucose/bio1:rxn03393_c0> needed:0.0 with min obj:0.01
# 1707857665.027925 INFO: Carbon-D-Glucose/bio1:rxn11702_c0> needed:0.0 with min obj:0.01
# 1707857665.031414 INFO: Carbon-D-Glucose/bio1:rxn05117_c0> needed:0.0 with min obj:0.01
# 1707857665.037954 INFO: Carbon-D-Glucose/bio1:rxn01790_c0< needed:0.0 with min obj:0.01
# 1707857665.0417778 INFO: Carbon-D-Glucose/bio1:rxn03394_c0> needed:0.0 with min obj:0.01
# 1707857665.0451992 INFO: Carbon-D-Glucose/bio1:rxn05144_c0> needed:0.0 with min obj:0.01
# 1707857665.0490189 INFO: Carbon-D-Glucose/bio1:rxn02831_c0> needed:0.0 with min obj:0.01
# 1707857665.05264 INFO: Carbon-D-Glucose/bio1:rxn01258_c0> needed:0.0 with min obj:0.01
# 1707857665.056152 INFO: Carbon-D-Glucose/bio1:rxn02832_c0< needed:0.0 with min obj:0.01
# 1707857665.059546 INFO: Carbon-D-Glucose/bio1:rxn09232_c0< needed:0.0 with min obj:0.01
# 1707857665.062965 INFO: Carbon-D-Glucose/bio1:rxn08233_c0> needed:0.0 with min obj:0.01
# Adding gapfilling {'growth': 0.5416425530052867, 'media': <cobrakbase.core.kbasebiochem.media.Media object at 0x7fdb0c13c7f0>, 'target': 'bio1', 'minobjective': 0.01, 'binary_check': False, 'new': {'EX_cpd00027_e0': '<', 'EX_cpd00099_e0': '<', 'rxn03086_c0': '<', 'rxn08333_c0': '>', 'rxn02898_c0': '>', 'rxn05459_c0': '>', 'rxn00565_c0': '>', 'rxn00068_c0': '<', 'rxn00957_c0': '>', 'rxn00625_c0': '<', 'rxn10213_c0': '>', 'rxn02404_c0': '>', 'rxn05039_c0': '>', 'rxn05573_c0': '>', 'rxn01444_c0': '>', 'rxn09233_c0': '>', 'rxn03397_c0': '>', 'rxn01972_c0': '>', 'rxn00979_c0': '>', 'rxn09106_c0': '>', 'rxn01539_c0': '<', 'rxn10094_c0': '>', 'rxn01508_c0': '>', 'rxn03150_c0':
# 1707857708.807467 INFO: Expansion time:Pyr.TMAO:0.5399648220009112
# 1707857708.8084302 INFO: Filtered count:0 out of 0
# 1707857709.410804 INFO: Expansion time:Succ.O2:0.601563152999006
# 1707857709.4116852 INFO: Filtered count:0 out of 0
# 1707857709.954273 INFO: Expansion time:empty:0.5418028439999034
# 1707857709.955262 INFO: Filtered count:0 out of 0
# 1707857713.034176 INFO: cpd15574 not found in model!
# 1707857713.035378 INFO: Media compound: cpd15574 not found in model.
# 1707857713.036273 INFO: cpd03396 not found in model!
# 1707857713.0380192 INFO: Media compound: cpd03396 not found in model.
# 1707857713.039285 INFO: cpd03387 not found in model!
# 1707857713.040755 INFO: Media compound: cpd03387 not found in model.
# 1707857713.0640059 INFO: GlucoseM9MinMedia/bio1:EX_cpd00027_e0< needed:0.0 with min obj:0.01
# 1707857713.07224 INFO: GlucoseM9MinMedia/bio1:EX_cpd00099_e0< needed:0.0 with min obj:0.01
# 1707857713.095674 INFO: GlucoseM9MinMedia/bio1:rxn03086_c0< needed:0.0 with min obj:0.01
# 1707857713.102151 INFO: GlucoseM9MinMedia/bio1:rxn08333_c0> needed:0.0 with min obj:0.01
# 1707857713.1075 INFO: GlucoseM9MinMedia/bio1:rxn02898_c0> needed:0.0 with min obj:0.01
# 1707857713.113018 INFO: GlucoseM9MinMedia/bio1:rxn05459_c0> needed:0.0 with min obj:0.01
# 1707857713.118054 INFO: GlucoseM9MinMedia/bio1:rxn00565_c0> needed:0.0 with min obj:0.01
# 1707857713.1363049 INFO: GlucoseM9MinMedia/bio1:rxn00068_c0< needed:0.0 with min obj:0.01
# 1707857713.142307 INFO: GlucoseM9MinMedia/bio1:rxn00957_c0> needed:0.0 with min obj:0.01
# 1707857713.157187 INFO: GlucoseM9MinMedia/bio1:rxn00625_c0< needed:0.0 with min obj:0.01
# 1707857713.1627672 INFO: GlucoseM9MinMedia/bio1:rxn10213_c0> needed:0.0 with min obj:0.01
# 1707857713.1692102 INFO: GlucoseM9MinMedia/bio1:rxn02404_c0> needed:0.0 with min obj:0.01
# 1707857713.248333 INFO: GlucoseM9MinMedia/bio1:rxn05039_c0> needed:0.0 with min obj:0.01
# 1707857713.263069 INFO: GlucoseM9MinMedia/bio1:rxn05573_c0> needed:0.0 with min obj:0.01
# 1707857713.277834 INFO: GlucoseM9MinMedia/bio1:rxn01444_c0> needed:0.0 with min obj:0.01
# 1707857713.293943 INFO: GlucoseM9MinMedia/bio1:rxn09233_c0> needed:0.0 with min obj:0.01
# 1707857713.30838 INFO: GlucoseM9MinMedia/bio1:rxn03397_c0> needed:0.0 with min obj:0.01
# 1707857713.3141398 INFO: GlucoseM9MinMedia/bio1:rxn01972_c0> needed:0.0 with min obj:0.01
# 1707857713.318881 INFO: GlucoseM9MinMedia/bio1:rxn00979_c0> needed:0.0 with min obj:0.01
# 1707857713.324564 INFO: GlucoseM9MinMedia/bio1:rxn09106_c0> needed:0.0 with min obj:0.01
# 1707857713.329901 INFO: GlucoseM9MinMedia/bio1:rxn01539_c0< needed:0.0 with min obj:0.01
# 1707857713.335327 INFO: GlucoseM9MinMedia/bio1:rxn10094_c0> needed:0.0 with min obj:0.01
# 1707857713.340567 INFO: GlucoseM9MinMedia/bio1:rxn01508_c0> needed:0.0 with min obj:0.01
# 1707857713.351732 INFO: GlucoseM9MinMedia/bio1:rxn03150_c0> needed:0.0 with min obj:0.01
# 1707857713.357253 INFO: GlucoseM9MinMedia/bio1:rxn09310_c0> needed:0.0 with min obj:0.01
# 1707857713.3623 INFO: GlucoseM9MinMedia/bio1:rxn01213_c0> needed:0.0 with min obj:0.01
# 1707857713.367609 INFO: GlucoseM9MinMedia/bio1:rxn02304_c0> needed:0.0 with min obj:0.01
# 1707857713.373352 INFO: GlucoseM9MinMedia/bio1:rxn12239_c0> needed:0.0 with min obj:0.01
# 1707857713.378945 INFO: GlucoseM9MinMedia/bio1:rxn03393_c0> needed:0.0 with min obj:0.01
# 1707857713.384613 INFO: GlucoseM9MinMedia/bio1:rxn11702_c0> needed:0.0 with min obj:0.01
# 1707857713.390864 INFO: GlucoseM9MinMedia/bio1:rxn05117_c0> needed:0.0 with min obj:0.01
# 1707857713.400198 INFO: GlucoseM9MinMedia/bio1:rxn01790_c0< needed:0.0 with min obj:0.01
# 1707857713.405746 INFO: GlucoseM9MinMedia/bio1:rxn03394_c0> needed:0.0 with min obj:0.01
# 1707857713.4108999 INFO: GlucoseM9MinMedia/bio1:rxn05144_c0> needed:0.0 with min obj:0.01
# 1707857713.489147 INFO: GlucoseM9MinMedia/bio1:rxn02831_c0> needed:0.0 with min obj:0.01
# 1707857713.494487 INFO: GlucoseM9MinMedia/bio1:rxn01258_c0> needed:0.0 with min obj:0.01
# 1707857713.5002172 INFO: GlucoseM9MinMedia/bio1:rxn02832_c0< needed:0.0 with min obj:0.01
# 1707857713.506151 INFO: GlucoseM9MinMedia/bio1:rxn09232_c0< needed:0.0 with min obj:0.01
# 1707857713.511892 INFO: GlucoseM9MinMedia/bio1:rxn08233_c0> needed:0.0 with min obj:0.01
# 1707857713.837922 INFO: cpd15574 not found in model!
# 1707857713.838924 INFO: Media compound: cpd15574 not found in model.
# 1707857713.839742 INFO: cpd03396 not found in model!
# 1707857713.841324 INFO: Media compound: cpd03396 not found in model.
# 1707857713.84261 INFO: cpd03387 not found in model!
# 1707857713.843916 INFO: Media compound: cpd03387 not found in model.
# Adding gapfilling {'growth': 1.0832851060106117, 'media': <cobrakbase.core.kbasebiochem.media.Media object at 0x7fdaf36c7fd0>, 'target': 'bio1', 'minobjective': 0.01, 'binary_check': False, 'new': {'EX_cpd00027_e0': '<', 'EX_cpd00099_e0': '<', 'rxn03086_c0': '<', 'rxn08333_c0': '>', 'rxn02898_c0': '>', 'rxn05459_c0': '>', 'rxn00565_c0': '>', 'rxn00068_c0': '<', 'rxn00957_c0': '>', 'rxn00625_c0': '<', 'rxn10213_c0': '>', 'rxn02404_c0': '>', 'rxn05039_c0': '>', 'rxn05573_c0': '>', 'rxn01444_c0': '>', 'rxn09233_c0': '>', 'rxn03397_c0': '>', 'rxn01972_c0': '>', 'rxn00979_c0
# 1707857768.48721 INFO: Expansion time:Pyr.SO4:0.727323900002375
# 1707857768.488362 INFO: Filtered count:0 out of 2
# 1707857769.19156 INFO: Expansion time:Pyr.TMAO:0.7020310949992563
# 1707857769.1928709 INFO: Filtered count:0 out of 2
# 1707857770.108858 INFO: Expansion time:Succ.O2:0.9145763769993209
# 1707857770.110177 INFO: Filtered count:0 out of 2
# 1707857770.871901 INFO: Expansion time:empty:0.7597108579975611
# 1707857770.87303 INFO: Filtered count:0 out of 2
# 1707857774.9555788 INFO: cpd15574 not found in model!
# 1707857774.956737 INFO: Media compound: cpd15574 not found in model.
# 1707857774.95764 INFO: cpd03396 not found in model!
# 1707857774.9592 INFO: Media compound: cpd03396 not found in model.
# 1707857774.960638 INFO: cpd03387 not found in model!
# 1707857774.962074 INFO: Media compound: cpd03387 not found in model.
# 1707857774.9886742 INFO: EX_cpd00027_e0< not needed:1.4198397020527163
# 1707857774.998676 INFO: NAGM9MinMedia/bio1:EX_cpd00099_e0< needed:0.0 with min obj:0.01
# 1707857775.00488 INFO: NAGM9MinMedia/bio1:rxn03086_c0< needed:0.0 with min obj:0.01
# 1707857775.010311 INFO: NAGM9MinMedia/bio1:rxn08333_c0> needed:0.0 with min obj:0.01
# 1707857775.01535 INFO: NAGM9MinMedia/bio1:rxn02898_c0> needed:0.0 with min obj:0.01
# 1707857775.020791 INFO: NAGM9MinMedia/bio1:rxn05459_c0> needed:0.0 with min obj:0.01
# 1707857775.026583 INFO: NAGM9MinMedia/bio1:rxn00565_c0> needed:0.0 with min obj:0.01
# 1707857775.069188 INFO: NAGM9MinMedia/bio1:rxn00068_c0< needed:0.0 with min obj:0.01
# 1707857775.07477 INFO: NAGM9MinMedia/bio1:rxn00957_c0> needed:0.0 with min obj:0.01
# 1707857775.079659 INFO: NAGM9MinMedia/bio1:rxn00625_c0< needed:0.0 with min obj:0.01
# 1707857775.0988648 INFO: NAGM9MinMedia/bio1:rxn10213_c0> needed:0.0 with min obj:0.01
# 1707857775.104259 INFO: NAGM9MinMedia/bio1:rxn02404_c0> needed:0.0 with min obj:0.01
# 1707857775.1099489 INFO: NAGM9MinMedia/bio1:rxn05039_c0> needed:0.0 with min obj:0.01
# 1707857775.122219 INFO: rxn05573_c0> not needed:1.4198397020527267
# 1707857775.1295 INFO: NAGM9MinMedia/bio1:rxn01444_c0> needed:0.0 with min obj:0.01
# 1707857775.171306 INFO: NAGM9MinMedia/bio1:rxn09233_c0> needed:0.0 with min obj:0.01
# 1707857775.212554 INFO: NAGM9MinMedia/bio1:rxn03397_c0> needed:0.0 with min obj:0.01
# 1707857775.21926 INFO: NAGM9MinMedia/bio1:rxn01972_c0> needed:0.0 with min obj:0.01
# 1707857775.226089 INFO: NAGM9MinMedia/bio1:rxn00979_c0> needed:0.0 with min obj:0.01
# 1707857775.2322261 INFO: NAGM9MinMedia/bio1:rxn09106_c0> needed:0.0 with min obj:0.01
# 1707857775.237493 INFO: NAGM9MinMedia/bio1:rxn01539_c0< needed:0.0 with min obj:0.01
# 1707857775.243277 INFO: NAGM9MinMedia/bio1:rxn10094_c0> needed:0.0 with min obj:0.01
# 1707857775.248729 INFO: NAGM9MinMedia/bio1:rxn01508_c0> needed:0.0 with min obj:0.01
# 1707857775.2534962 INFO: NAGM9MinMedia/bio1:rxn03150_c0> needed:0.0 with min obj:0.01
# 1707857775.258368 INFO: NAGM9MinMedia/bio1:rxn09310_c0> needed:0.0 with min obj:0.01
# 1707857775.26378 INFO: NAGM9MinMedia/bio1:rxn01213_c0> needed:0.0 with min obj:0.01
# 1707857775.269144 INFO: NAGM9MinMedia/bio1:rxn02304_c0> needed:0.0 with min obj:0.01
# 1707857775.27517 INFO: NAGM9MinMedia/bio1:rxn12239_c0> needed:0.0 with min obj:0.01
# 1707857775.280968 INFO: NAGM9MinMedia/bio1:rxn03393_c0> needed:0.0 with min obj:0.01
# 1707857775.2870982 INFO: NAGM9MinMedia/bio1:rxn11702_c0> needed:0.0 with min obj:0.01
# 1707857775.292924 INFO: NAGM9MinMedia/bio1:rxn05117_c0> needed:0.0 with min obj:0.01
# 1707857775.29872 INFO: NAGM9MinMedia/bio1:rxn01790_c0< needed:0.0 with min obj:0.01
# 1707857775.305192 INFO: NAGM9MinMedia/bio1:rxn03394_c0> needed:0.0 with min obj:0.01
# 1707857775.3113248 INFO: NAGM9MinMedia/bio1:rxn05144_c0> needed:0.0 with min obj:0.01
# 1707857775.317173 INFO: NAGM9MinMedia/bio1:rxn02831_c0> needed:0.0 with min obj:0.01
# 1707857775.322612 INFO: NAGM9MinMedia/bio1:rxn01258_c0> needed:0.0 with min obj:0.01
# 1707857775.328799 INFO: NAGM9MinMedia/bio1:rxn02832_c0< needed:0.0 with min obj:0.01
# 1707857775.334976 INFO: NAGM9MinMedia/bio1:rxn09232_c0< needed:0.0 with min obj:0.01
# 1707857775.3500302 INFO: NAGM9MinMedia/bio1:rxn08233_c0> needed:0.0 with min obj:0.01
# 1707857775.3613389 INFO: NAGM9MinMedia/bio1:EX_cpd00122_e0< needed:0.0 with min obj:0.01
# 1707857775.423347 INFO: NAGM9MinMedia/bio1:rxn05485_c0> needed:0.0 with min obj:0.01
# 1707857775.624817 INFO: cpd15574 not found in model!
# 1707857775.626058 INFO: Media compound: cpd15574 not found in model.
# 1707857775.6269372 INFO: cpd03396 not found in model!
# 1707857775.628473 INFO: Media compound: cpd03396 not found in model.
# 1707857775.629813 INFO: cpd03387 not found in model!
# 1707857775.6313002 INFO: Media compound: cpd03387 not found in model.
# 1707857775.821183 INFO: cpd15574 not found in model!
# 1707857775.82242 INFO: Media compound: cpd15574 not found in model.
# 1707857775.823335 INFO: cpd03396 not found in model!
# 1707857775.824372 INFO: Media compound: cpd03396 not found in model.
# 1707857775.825699 INFO: cpd03387 not found in model!
# 1707857775.827154 INFO: Media compound: cpd03387 not found in model.
# Adding gapfilling {'growth': 1.4198397020526932, 'media': <cobrakbase.core.kbasebiochem.media.Media object at 0x7fdaf36c7df0>, 'target': 'bio1', 'minobjective': 0.01, 'binary_check': False, 'new': {'EX_cpd00099_e0': '<', 'rxn03086_c0': '<', 'rxn08333_c0': '>', 'rxn02898_c0': '>', 'rxn05459_c0': '>', 'rxn00565_c0': '>', 'rxn00068_c0': '<', 'rxn00957_c0': '>', 'rxn00625_c0': '<', 'rxn10213_c0': '>', 'rxn02404_c0': '>', 'rxn05039_c0': '>', 'rxn01444_c0': '>', 'rxn09233_c0': '>', 'rxn03397_c0': '>', 'rxn01972_c0': '>', 'rxn00979_c0': '>', 'rxn09106_c0': '>', 'rxn01539_c0': '<', 'rxn10094_c0': '>', 'rxn01508_c0': '>', 'rxn03150_c0': '>', 'rxn09310_c0': '>', 'rxn01213_c0': '>', 'rxn02304_c0': '>', 'rxn12239_c0': '>', 'rxn03393_c0': '>', 'rxn11702_c0': '>', 'rxn05117_c0': '>', 'rxn01790_c0': '<', 'rxn03394_c0': '>', 'rxn05144_c0': '>', 'rxn02831_c0': '>', 'rxn01258_c0': '>', 'rxn02832_c0': '<', 'rxn09232_c0': '<', 'rxn08233_c0': '>', 'EX_cpd00122_e0': '<', 'rxn05485_c0': '>'}, 'reversed': {}}
# 1707857791.915761 INFO: Objective with gapfill database:0.8445374971944319; min objective:0.01
# 1707857809.6551418 INFO: Expansion time:Ac.NO2:1.0234401899979275
# 1707857809.65606 INFO: Filtered count:0 out of 2
# 1707857810.27653 INFO: Expansion time:Ac.NO3:0.6196493389979878
# 1707857810.2773602 INFO: Filtered count:0 out of 2
# 1707857810.879339 INFO: Expansion time:Ac.O2:0.6012179429999378
# 1707857810.880191 INFO: Filtered count:0 out of 2
# 1707857811.384065 INFO: Expansion time:Dlac.O2:0.5031522440003755
# 1707857811.384903 INFO: Filtered count:0 out of 2
# 1707857811.898172 INFO: Expansion time:Etho.O2:0.5124908790021436
# 1707857811.899061 INFO: Filtered count:0 out of 2
# 1707857812.4310029 INFO: Expansion time:For.NO2:0.5311619200001587
# 1707857812.43194 INFO: Filtered count:0 out of 2
# 1707857812.954656 INFO: Expansion time:For.NO3:0.5219141259985918
# 1707857812.95579 INFO: Filtered count:0 out of 2
# 1707857818.603542 INFO: Expansion time:For.O2:5.646840060002432
# 1707857818.604793 INFO: Filtered count:0 out of 2
# 1707857819.232713 INFO: Expansion time:Fum:0.6266734560012992
# 1707857819.233768 INFO: Filtered count:0 out of 2
# 1707857819.826896 INFO: Expansion time:Fum.O2:0.592314053003065
# 1707857819.827743 INFO: Filtered count:0 out of 2
# 1707857820.438166 INFO: Expansion time:Glyc:0.6096093050000491
# 1707857820.4392 INFO: Filtered count:0 out of 2
# 1707857821.01458 INFO: Expansion time:Glyc.O2:0.5745204459999513
# 1707857821.015452 INFO: Filtered count:0 out of 2
# 1707857821.5700622 INFO: Expansion time:Pyr:0.5537039810005808
# 1707857821.570878 INFO: Filtered count:0 out of 2
# 1707857822.057664 INFO: Expansion time:Pyr.DMSO:0.4860729430001811
# 1707857822.0585332 INFO: Filtered count:0 out of 2
# 1707857822.532468 INFO: Expansion time:Pyr.NO:0.47323995099941385
# 1707857822.5333319 INFO: Filtered count:0 out of 2
# 1707857823.084214 INFO: Expansion time:Pyr.NO2:0.5501245640007255
# 1707857823.084996 INFO: Filtered count:0 out of 2
# 1707857823.606418 INFO: Expansion time:Pyr.NO3:0.5206876500014914
# 1707857823.607316 INFO: Filtered count:0 out of 2
# 1707857824.1158268 INFO: Expansion time:Pyr.O2:0.5078535880020354
# 1707857824.116668 INFO: Filtered count:0 out of 2
# 1707857824.661432 INFO: Expansion time:Pyr.SO3:0.5441013900017424
# ...
# 1707858056.726138 INFO: Filtered count:0 out of 2
# 1707858059.009355 INFO: cpd15574 not found in model!
# 1707858059.01013 INFO: Media compound: cpd15574 not found in model.
# 1707858059.010772 INFO: cpd03396 not found in model!
# 1707858059.011947 INFO: Media compound: cpd03396 not found in model.
# 1707858059.0127192 INFO: cpd03387 not found in model!
# 1707858059.013681 INFO: Media compound: cpd03387 not found in model.
# 1707858059.030421 INFO: EX_cpd00027_e0< not needed:1.1148370993895542
# 1707858059.034307 INFO: FructoseM9MinMedia/bio1:EX_cpd00099_e0< needed:0.0 with min obj:0.01
# 1707858059.037798 INFO: FructoseM9MinMedia/bio1:rxn03086_c0< needed:0.0 with min obj:0.01
# 1707858059.041018 INFO: FructoseM9MinMedia/bio1:rxn08333_c0> needed:0.0 with min obj:0.01
# 1707858059.044564 INFO: FructoseM9MinMedia/bio1:rxn02898_c0> needed:0.0 with min obj:0.01
# 1707858059.0481741 INFO: FructoseM9MinMedia/bio1:rxn05459_c0> needed:0.0 with min obj:0.01
# 1707858059.051602 INFO: FructoseM9MinMedia/bio1:rxn00565_c0> needed:0.0 with min obj:0.01
# 1707858059.054962 INFO: FructoseM9MinMedia/bio1:rxn00068_c0< needed:0.0 with min obj:0.01
# 1707858059.058371 INFO: FructoseM9MinMedia/bio1:rxn00957_c0> needed:0.0 with min obj:0.01
# 1707858059.0618172 INFO: FructoseM9MinMedia/bio1:rxn00625_c0< needed:0.0 with min obj:0.01
# 1707858059.0650828 INFO: FructoseM9MinMedia/bio1:rxn10213_c0> needed:0.0 with min obj:0.01
# 1707858059.0684319 INFO: FructoseM9MinMedia/bio1:rxn02404_c0> needed:0.0 with min obj:0.01
# 1707858059.071758 INFO: FructoseM9MinMedia/bio1:rxn05039_c0> needed:0.0 with min obj:0.01
# 1707858059.075753 INFO: rxn05573_c0> not needed:1.1148370993895542
# 1707858059.079766 INFO: FructoseM9MinMedia/bio1:rxn01444_c0> needed:0.0 with min obj:0.01
# 1707858059.094749 INFO: FructoseM9MinMedia/bio1:rxn09233_c0> needed:0.0 with min obj:0.01
# 1707858059.118946 INFO: FructoseM9MinMedia/bio1:rxn03397_c0> needed:0.0 with min obj:0.01
# 1707858059.122445 INFO: FructoseM9MinMedia/bio1:rxn01972_c0> needed:0.0 with min obj:0.01
# 1707858059.125963 INFO: FructoseM9MinMedia/bio1:rxn00979_c0> needed:0.0 with min obj:0.01
# 1707858059.129457 INFO: FructoseM9MinMedia/bio1:rxn09106_c0> needed:0.0 with min obj:0.01
# 1707858059.132833 INFO: FructoseM9MinMedia/bio1:rxn01539_c0< needed:0.0 with min obj:0.01
# 1707858059.136116 INFO: FructoseM9MinMedia/bio1:rxn10094_c0> needed:0.0 with min obj:0.01
# 1707858059.13945 INFO: FructoseM9MinMedia/bio1:rxn01508_c0> needed:0.0 with min obj:0.01
# 1707858059.142716 INFO: FructoseM9MinMedia/bio1:rxn03150_c0> needed:0.0 with min obj:0.01
# 1707858059.146194 INFO: FructoseM9MinMedia/bio1:rxn09310_c0> needed:0.0 with min obj:0.01
# 1707858059.1499462 INFO: FructoseM9MinMedia/bio1:rxn01213_c0> needed:0.0 with min obj:0.01
# 1707858059.153384 INFO: FructoseM9MinMedia/bio1:rxn02304_c0> needed:0.0 with min obj:0.01
# 1707858059.1570072 INFO: FructoseM9MinMedia/bio1:rxn12239_c0> needed:0.0 with min obj:0.01
# 1707858059.160587 INFO: FructoseM9MinMedia/bio1:rxn03393_c0> needed:0.0 with min obj:0.01
# 1707858059.164202 INFO: FructoseM9MinMedia/bio1:rxn11702_c0> needed:0.0 with min obj:0.01
# 1707858059.168085 INFO: FructoseM9MinMedia/bio1:rxn05117_c0> needed:0.0 with min obj:0.01
# 1707858059.1800709 INFO: FructoseM9MinMedia/bio1:rxn01790_c0< needed:0.0 with min obj:0.01
# 1707858059.1838589 INFO: FructoseM9MinMedia/bio1:rxn03394_c0> needed:0.0 with min obj:0.01
# 1707858059.1873689 INFO: FructoseM9MinMedia/bio1:rxn05144_c0> needed:0.0 with min obj:0.01
# 1707858059.190901 INFO: FructoseM9MinMedia/bio1:rxn02831_c0> needed:0.0 with min obj:0.01
# 1707858059.1947489 INFO: FructoseM9MinMedia/bio1:rxn01258_c0> needed:0.0 with min obj:0.01
# 1707858059.198433 INFO: FructoseM9MinMedia/bio1:rxn02832_c0< needed:0.0 with min obj:0.01
# 1707858059.2019289 INFO: FructoseM9MinMedia/bio1:rxn09232_c0< needed:0.0 with min obj:0.01
# 1707858059.205604 INFO: FructoseM9MinMedia/bio1:rxn08233_c0> needed:0.0 with min obj:0.01
# 1707858059.212398 INFO: EX_cpd00122_e0< not needed:1.1148370993895478
# 1707858059.21457 INFO: rxn05485_c0> not needed:1.1148370993895478
# 1707858059.216555 INFO: EX_cpd00054_e0< not needed:1.1148370993895478
# 1707858059.218664 INFO: rxn05307_c0> not needed:1.1148370993895478
# 1707858059.2205791 INFO: EX_cpd00035_e0< not needed:1.1148370993895478
# 1707858059.222684 INFO: rxn05496_c0> not needed:1.1148370993895478
# 1707858059.22457 INFO: EX_cpd00023_e0< not needed:1.1148370993895478
# 1707858059.2265441 INFO: rxn05297_c0> not needed:1.1148370993895478
# 1707858059.2286038 INFO: EX_cpd00076_e0< not needed:1.1148370993895478
# 1707858059.2306418 INFO: rxn05655_c0> not needed:1.1148370993895478
# 1707858059.232569 INFO: rxn02760_c0> not needed:1.1148370993895478
# 1707858059.2345018 INFO: FructoseM9MinMedia/bio1:EX_cpd00082_e0< needed:0.0 with min obj:0.01
# 1707858059.239181 INFO: FructoseM9MinMedia/bio1:rxn05560_c0> needed:0.0 with min obj:0.01
# 1707858059.3724318 INFO: cpd15574 not found in model!
# 1707858059.37319 INFO: Media compound: cpd15574 not found in model.
# 1707858059.3738198 INFO: cpd03396 not found in model!
# 1707858059.374841 INFO: Media compound: cpd03396 not found in model.
# 1707858059.3755121 INFO: cpd03387 not found in model!
# 1707858059.376559 INFO: Media compound: cpd03387 not found in model.
# 1707858059.505812 INFO: cpd15574 not found in model!
# 1707858059.5066528 INFO: Media compound: cpd15574 not found in model.
# 1707858059.5072482 INFO: cpd03396 not found in model!
# 1707858059.508238 INFO: Media compound: cpd03396 not found in model.
# 1707858059.508929 INFO: cpd03387 not found in model!
# 1707858059.5097651 INFO: Media compound: cpd03387 not found in model.
# Adding gapfilling {'growth': 1.1148370993895445, 'media': <cobrakbase.core.kbasebiochem.media.Media object at 0x7fdb36e491f0>, 'target': 'bio1', 'minobjective': 0.01, 'binary_check': False, 'new': {'EX_cpd00099_e0': '<', 'rxn03086_c0': '<', 'rxn08333_c0': '>', 'rxn02898_c0': '>', 'rxn05459_c0': '>', 'rxn00565_c0': '>', 'rxn00068_c0': '<', 'rxn00957_c0': '>', 'rxn00625_c0': '<', 'rxn10213_c0': '>', 'rxn02404_c0': '>', 'rxn05039_c0': '>', 'rxn01444_c0': '>', 'rxn09233_c0': '>', 'rxn03397_c0': '>', 'rxn01972_c0': '>', 'rxn00979_c0': '>', 'rxn09106_c0': '>', 'rxn01539_c0': '<', 'rxn10094_c0': '>', 'rxn01508_c0': '>', 'rxn03150_c0': '>', 'rxn09310_c0': '>', 'rxn01213_c0': '>', 'rxn02304_c0': '>', 'rxn12239_c0': '>', 'rxn03393_c0': '>', 'rxn11702_c0': '>', 'rxn05117_c0': '>', 'rxn01790_c0': '<', 'rxn03394_c0': '>', 'rxn05144_c0': '>', 'rxn02831_c0': '>', 'rxn01258_c0': '>', 'rxn02832_c0': '<', 'rxn09232_c0': '<', 'rxn08233_c0': '>', 'EX_cpd00082_e0': '<', 'rxn05560_c0': '>'}, 'reversed': {}}
# 1707858075.941611 INFO: Objective with gapfill database:1.4075624953244168; min objective:0.01
# 1707858090.363246 INFO: Expansion time:Ac.NO2:0.8486630300030811
# 1707858090.3640609 INFO: Filtered count:0 out of 1
# 1707858090.869369 INFO: Expansion time:Ac.NO3:0.5045210329990368
# 1707858090.870214 INFO: Filtered count:0 out of 1
# 1707858091.387636 INFO: Expansion time:Ac.O2:0.5165934800024843
# 1707858091.388454 INFO: Filtered count:0 out of 1
# 1707858091.861142 INFO: Expansion time:Dlac.O2:0.4719740719992842
# 1707858091.861907 INFO: Filtered count:0 out of 1
# 1707858092.3253279 INFO: Expansion time:Etho.O2:0.462727158999769
# 1707858092.3261309 INFO: Filtered count:0 out of 1
# 1707858092.860663 INFO: Expansion time:For.NO2:0.5338054099993315
# 1707858092.861453 INFO: Filtered count:0 out of 1
# 1707858093.4302762 INFO: Expansion time:For.NO3:0.5681543700011389
# 1707858093.431036 INFO: Filtered count:0 out of 1
# 1707858093.9093409 INFO: Expansion time:For.O2:0.47760883499722695
# 1707858093.910159 INFO: Filtered count:0 out of 1
# 1707858104.0877178 INFO: ArabinoseM9MinMedia/bio1:rxn00068_c0< needed:0.0 with min obj:0.01
# 1707858104.091485 INFO: ArabinoseM9MinMedia/bio1:rxn00957_c0> needed:0.0 with min obj:0.01
# 1707858104.095316 INFO: ArabinoseM9MinMedia/bio1:rxn00625_c0< needed:0.0 with min obj:0.01
# 1707858104.1067488 INFO: ArabinoseM9MinMedia/bio1:rxn10213_c0> needed:0.0 with min obj:0.01
# 1707858104.1107461 INFO: ArabinoseM9MinMedia/bio1:rxn02404_c0> needed:0.0 with min obj:0.01
# 1707858104.1148312 INFO: ArabinoseM9MinMedia/bio1:rxn05039_c0> needed:0.0 with min obj:0.01
# 1707858104.1225972 INFO: rxn05573_c0> not needed:0.8573213907329572
# 1707858104.1275818 INFO: ArabinoseM9MinMedia/bio1:rxn01444_c0> needed:0.0 with min obj:0.01
# 1707858104.1410291 INFO: ArabinoseM9MinMedia/bio1:rxn09233_c0> needed:0.0 with min obj:0.01
# 1707858104.144854 INFO: ArabinoseM9MinMedia/bio1:rxn03397_c0> needed:0.0 with min obj:0.01
# 1707858104.1485372 INFO: ArabinoseM9MinMedia/bio1:rxn01972_c0> needed:0.0 with min obj:0.01
# 1707858104.152171 INFO: ArabinoseM9MinMedia/bio1:rxn00979_c0> needed:0.0 with min obj:0.01
# 1707858104.155752 INFO: ArabinoseM9MinMedia/bio1:rxn09106_c0> needed:0.0 with min obj:0.01
# 1707858104.15929 INFO: ArabinoseM9MinMedia/bio1:rxn01539_c0< needed:0.0 with min obj:0.01
# 1707858104.1629 INFO: ArabinoseM9MinMedia/bio1:rxn10094_c0> needed:0.0 with min obj:0.01
# 1707858104.166613 INFO: ArabinoseM9MinMedia/bio1:rxn01508_c0> needed:0.0 with min obj:0.01
# 1707858104.1700559 INFO: ArabinoseM9MinMedia/bio1:rxn03150_c0> needed:0.0 with min obj:0.01
# 1707858104.173594 INFO: ArabinoseM9MinMedia/bio1:rxn09310_c0> needed:0.0 with min obj:0.01
# 1707858104.177355 INFO: ArabinoseM9MinMedia/bio1:rxn01213_c0> needed:0.0 with min obj:0.01
# 1707858104.180937 INFO: ArabinoseM9MinMedia/bio1:rxn02304_c0> needed:0.0 with min obj:0.01
# 1707858104.184403 INFO: ArabinoseM9MinMedia/bio1:rxn12239_c0> needed:0.0 with min obj:0.01
# 1707858104.188184 INFO: ArabinoseM9MinMedia/bio1:rxn03393_c0> needed:0.0 with min obj:0.01
# 1707858104.192124 INFO: ArabinoseM9MinMedia/bio1:rxn11702_c0> needed:0.0 with min obj:0.01
# 1707858104.195986 INFO: ArabinoseM9MinMedia/bio1:rxn05117_c0> needed:0.0 with min obj:0.01
# 1707858104.2006881 INFO: ArabinoseM9MinMedia/bio1:rxn01790_c0< needed:0.0 with min obj:0.01
# 1707858104.2049391 INFO: ArabinoseM9MinMedia/bio1:rxn03394_c0> needed:0.0 with min obj:0.01
# 1707858104.208541 INFO: ArabinoseM9MinMedia/bio1:rxn05144_c0> needed:0.0 with min obj:0.01
# 1707858104.212418 INFO: ArabinoseM9MinMedia/bio1:rxn02831_c0> needed:0.0 with min obj:0.01
# 1707858104.21613 INFO: ArabinoseM9MinMedia/bio1:rxn01258_c0> needed:0.0 with min obj:0.01
# 1707858104.2198021 INFO: ArabinoseM9MinMedia/bio1:rxn02832_c0< needed:0.0 with min obj:0.01
# 1707858104.22341 INFO: ArabinoseM9MinMedia/bio1:rxn09232_c0< needed:0.0 with min obj:0.01
# 1707858104.2270432 INFO: ArabinoseM9MinMedia/bio1:rxn08233_c0> needed:0.0 with min obj:0.01
# 1707858104.23507 INFO: EX_cpd00122_e0< not needed:0.8573213907329538
# 1707858104.237557 INFO: rxn05485_c0> not needed:0.8573213907329538
# 1707858104.239763 INFO: EX_cpd00054_e0< not needed:0.8573213907329538
# 1707858104.2419012 INFO: rxn05307_c0> not needed:0.8573213907329538
# 1707858104.244311 INFO: EX_cpd00035_e0< not needed:0.8573213907329538
# 1707858104.246625 INFO: rxn05496_c0> not needed:0.8573213907329538
# 1707858104.2487419 INFO: EX_cpd00023_e0< not needed:0.8573213907329538
# 1707858104.250871 INFO: rxn05297_c0> not needed:0.8573213907329538
# 1707858104.2530031 INFO: EX_cpd00076_e0< not needed:0.8573213907329538
# 1707858104.2552981 INFO: rxn05655_c0> not needed:0.8573213907329538
# 1707858104.25749 INFO: rxn02760_c0> not needed:0.8573213907329538
# 1707858104.259546 INFO: EX_cpd00082_e0< not needed:0.8573213907329538
# 1707858104.2617311 INFO: rxn05560_c0> not needed:0.8573213907329538
# 1707858104.266252 INFO: ArabinoseM9MinMedia/bio1:rxn01289_c0> needed:0.0 with min obj:0.01
# 1707858104.40312 INFO: cpd15574 not found in model!
# 1707858104.404027 INFO: Media compound: cpd15574 not found in model.
# 1707858104.404604 INFO: cpd03396 not found in model!
# 1707858104.405663 INFO: Media compound: cpd03396 not found in model.
# 1707858104.406383 INFO: cpd03387 not found in model!
# 1707858104.407339 INFO: Media compound: cpd03387 not found in model.
# 1707858104.541724 INFO: cpd15574 not found in model!
# 1707858104.542619 INFO: Media compound: cpd15574 not found in model.
# 1707858104.543284 INFO: cpd03396 not found in model!
# 1707858104.544245 INFO: Media compound: cpd03396 not found in model.
# 1707858104.544905 INFO: cpd03387 not found in model!
# 1707858104.54582 INFO: Media compound: cpd03387 not found in model.
# Adding gapfilling {'growth': 0.8573213907330439, 'media': <cobrakbase.core.kbasebiochem.media.Media object at 0x7fdb36e494f0>, 'target': 'bio1', 'minobjective': 0.01, 'binary_check': False, 'new': {'EX_cpd00099_e0': '<', 'rxn03086_c0': '<', 'rxn08333_c0': '>', 'rxn02898_c0': '>', 'rxn05459_c0': '>', 'rxn00565_c0': '>', 'rxn00068_c0': '<', 'rxn00957_c0': '>', 'rxn00625_c0': '<', 'rxn10213_c0': '>', 'rxn02404_c0': '>', 'rxn05039_c0': '>', 'rxn01444_c0': '>', 'rxn09233_c0': '>', 'rxn03397_c0': '>', 'rxn01972_c0': '>', 'rxn00979_c0': '>', 'rxn09106_c0': '>', 'rxn01539_c0': '<', 'rxn10094_c0': '>', 'rxn01508_c0': '>', 'rxn03150_c0': '>', 'rxn09310_c0': '>', 'rxn01213_c0': '>', 'rxn02304_c0': '>', 'rxn12239_c0': '>', 'rxn03393_c0': '>', 'rxn11702_c0': '>', 'rxn05117_c0': '>', 'rxn01790_c0': '<', 'rxn03394_c0': '>', 'rxn05144_c0': '>', 'rxn02831_c0': '>', 'rxn01258_c0': '>', 'rxn02832_c0': '<', 'rxn09232_c0': '<', 'rxn08233_c0': '>', 'rxn01289_c0': '>'}, 'reversed': {}}
# 1707858115.036675 INFO: Setting FBAModel computed_attributes to mdlutl attributes

# %%
genome_prefix = ["G8","G7","G5","G1","G16","G14","G12","G11"]
all_solutions = kbdevutil.load("all_solutions")
all_scores = kbdevutil.load("all_reaction_scores")
records = []
for prefix in genome_prefix:
    #model = msrecon.get_model("168913/"+prefix+"_RAST_prokka_assembly.glm4ec.mdl.gf")
    new_record = {"id":prefix}
    genome_id = "167956/"+prefix+"_RAST_prokka_assembly.glm4ec"
    if genome_id in all_solutions:
        for media in all_solutions[genome_id]:
            genes = 0
            scores = all_scores[genome_id]
            for rxn in all_solutions[genome_id][media]["new"]:
                #rxnobj = model.model.reactions.get_by_id(rxn)
                baseid = rxn.split("_")[0]
                if baseid in scores and len(scores[baseid]) > 0:
                    genes += 1
                    #print(rxn,rxnobj.reaction,scores[baseid]
            new_record[media] = str(len(all_solutions[genome_id][media]["new"]))+"/"+str(genes)
    records.append(new_record)
df = pd.DataFrame.from_records(records)
df.to_csv("gapfilling_results.tsv",index=False,sep="\t")

# %%
#Pulling super annotated ecoli genome
genome_ref = "77537/Eco_RAST_Prokka_BlastKOALA_PTools_DeepEC_DeepGO"
#Link to AnnotationOntology code in github:
annoont = AnnotationOntology.from_kbase_data(annoapi.get_annotation_ontology_events({
    "input_ref" : genome_ref
}),genome_ref)
scores = annoont.get_reaction_gene_hash(feature_type="gene")
kbdevutil.save("reaction_scores",scores)
# Out:
# 1707258151.927841 INFO: get_annotation_ontology_events:{
#     "input_ref": "77537/Eco_RAST_Prokka_BlastKOALA_PTools_DeepEC_DeepGO"
# }

# %% [markdown]
# # Code for creating ATP tests and checking changes in ATP test outcome

# %%
mdlutl_one = msrecon.get_model("151253/GCF_000005845.2.RAST.NewGMM.mdl")
MSPackageManager.get_pkg_mgr(mdlutl_one).getpkg("KBaseMediaPkg").build_package(msrecon.get_media("KBaseMedia/Carbon-D-Glucose"))
model = msrecon.get_model("168913/G8_RAST_prokka_assembly.glm4ec.mdl")
template = msrecon.get_template(model.model.template_ref)
tests = model.get_atp_tests()
msgapfill = MSGapfill(
    model,
    [template],
    [],
    tests,
    blacklist=[],
    default_target="bio1",
    minimum_obj=0.01,
)
MSPackageManager.get_pkg_mgr(msgapfill.gfmodelutl).getpkg("KBaseMediaPkg").build_package(msrecon.get_media("KBaseMedia/Carbon-D-Glucose"))
model_two = msgapfill.gfmodel
for rxn in mdlutl_one.model.reactions:
    if rxn.id not in model_two.reactions:
        print(rxn.id," missing in gf model")
    else:
        gfrxn = model_two.reactions.get_by_id(rxn.id)
        if rxn.upper_bound > gfrxn.upper_bound:
# EX_cpd00058_e0 Lower -100 0
# SK_cpd01042_c0  missing in gf model
# SK_cpd15302_c0  missing in gf model

# %% [markdown]
# # Code for checking if a model and a gapfilling model pass tests

# %%
#Pulling super annotated ecoli genome
genome_ref = "77537/Eco_RAST_Prokka_BlastKOALA_PTools_DeepEC_DeepGO"
#Link to AnnotationOntology code in github:
annoont = AnnotationOntology(annoapi.get_annotation_ontology_events({
    "input_ref" : genome_ref
}),genome_ref)
#You will call the get_reaction_gene_hash function of annoont to get the reaction gene hash
#Pulling ecoli model
model = msrecon.get_model("151253/GCF_000005845.2.RAST.NewGMM.mdl")
tests = model.get_atp_tests()
#Loading transcriptome
expression = pd.read_csv("ExpressionData.tsv",sep="\t")
#Getting template
template = msrecon.get_template(model.model.template_ref)
#Stripping out all reactions from template that are not in model except the reactions we want to keep to test exclusion
remove_list = []
#Keeping reactions we know are rejected because they break this model
keep_list = [
"rxn10157_c",
"rxn10155_c",
"rxn12575_c",
"rxn00704_c",
"rxn00778_c",
"rxn05206_c",
"rxn09193_c",
"rxn08234_c",
"rxn20583_c",
"rxn00154_c",
"rxn00145_c"
]
#rxn05289_c0
#rxn05469_c0
#rxn05654_c0
for rxn in template.reactions:
    if rxn.id+"0" not in model.model.reactions and rxn.id not in keep_list:
        remove_list.append(rxn)
template.remove_reactions(remove_list)
#Intentionally removing reactions related to our test media
#Serine,Malate,Adenosine,Fructose,Pyruvate
remove_ids = ["rxn05307_c0","rxn05605_c0","rxn05318_c0","rxn05560_c0","rxn05469_c0"]
remove_list = []
for item in remove_ids:
    rxn = model.model.reactions.get_by_id(item)
    remove_list.append(rxn)
#model.model.remove_reactions(remove_list)
#Making reaction scores
scores = annoont.get_reaction_gene_hash()
#Getting MSGapfill object
msgapfill = MSGapfill(
    model,
    [template],
    [],
    tests,
    blacklist=[],
    default_target="bio1",
    minimum_obj=0.01
)
print("Model test!")
model.test_condition_list(tests, model=model.model,positive_growth=[])
print("Gapfill model test!")
msgapfill.gfpkgmgr.getpkg("GapfillingPkg").reset_objective_minimum(0,False)
msgapfill.gfmodelutl.test_condition_list(tests,positive_growth=[])

# %% [markdown]
# # Code for comparing reaction content in two models and printing differences

# %%
#oldmodel = msrecon.get_model("151253/GCF_000005845.2.RAST.NewGMM.mdl")
oldmodel = model
for rxn in oldmodel.model.reactions:
    if rxn.id[0:3] != "EX_" and rxn.id in msgapfill.gfmodel.reactions:
        if rxn.upper_bound != msgapfill.gfmodel.reactions.get_by_id(rxn.id).upper_bound:
            print(rxn.id,"Upper",rxn.upper_bound,msgapfill.gfmodel.reactions.get_by_id(rxn.id).upper_bound)
        if rxn.lower_bound != msgapfill.gfmodel.reactions.get_by_id(rxn.id).lower_bound:
            print(rxn.id,"Lower",rxn.lower_bound,msgapfill.gfmodel.reactions.get_by_id(rxn.id).lower_bound)
    elif rxn.id[0:3] != "EX_":
        print(rxn.id,rxn.direction,"missing new model")
for rxn in msgapfill.gfmodel.reactions:
    if rxn.id not in oldmodel.model.reactions:
        print(rxn.id," missing old model")
